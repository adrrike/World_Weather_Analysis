# %%
# Import the dependencies
import pandas as pd
import matplotlib as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?"

#API URL
city_url = url + "q=" + city + "&appid=" + weather_api_key + "&units=imperial"

# Make a 'Get' request for the city weather.
weather_response = requests.get(city_url)

# Convert to json
weather_json = weather_response.json()

# API Test
weather_json.get("main")
# Out:
# {'temp': 48.47,
#  'feels_like': 48.47,
#  'temp_min': 48.47,
#  'temp_max': 48.47,
#  'pressure': 1010,
#  'humidity': 93,
#  'sea_level': 1010,
#  'grnd_level': 1003}

# %%
# Get the nearest city using the citipy module.
cities
# Out:
# ['bambous virieux',
#  'ushuaia',
#  'nioro',
#  'aksu',
#  'cabo san lucas',
#  'lolua',
#  'ambon',
#  'pevek',
#  'bethel',
#  'emerald',
#  'busselton',
#  'arraial do cabo',
#  'puerto ayora',
#  'hithadhoo',
#  'atuona',
#  'georgetown',
#  'paamiut',
#  'bubaque',
#  'kerki',
#  'tortoli',
#  'cheuskiny',
#  'kodiak',
#  'mount gambier',
#  'gat',
#  'longyearbyen',
#  'kautokeino',
#  'bredasdorp',
#  'narsaq',
#  'shingu',
#  'gamba',
#  'vestmannaeyjar',
#  'roald',
#  'sumbe',
#  'luderitz',
#  'carnarvon',
#  'sentyabrskiy',
#  'rikitea',
#  'qaanaaq',
#  'muroto',
#  'santa rosalia',
#  'sabzevar',
#  'allapalli',
#  'turayf',
#  'bluff',
#  'marsaxlokk',
#  'clyde river',
#  'tasiilaq',
#  'araouane',
#  'chuy',
#  'punta arenas',
#  'portland',
#  'cockburn town',
#  'kapoeta',
#  'leningradskiy',
#  'albany',
#  'ornskoldsvik',
#  'lata',
#  'hilo',
#  'njombe',
#  'palmer',
#  'dikson',
#  'hasaki',
#  'mar del plata',
#  'mataura',
#  'yevlax',
#  'sao joao da barra',
#  'pokaran',
#  'malumfashi',
#  'airai',
#  'kuala krai',
#  'altamira',
#  'eenhana',
#  'kutum',
#  'saint george',
#  'nanzhang',
#  'roros',
#  'andenes',
#  'aklavik',
#  'cape town',
#  'cabedelo',
#  'lakatoro',
#  'saint-pierre',
#  'tumannyy',
#  'port elizabeth',
#  'marathon',
#  'barentsburg',
#  'barrow',
#  'kapaa',
#  'mayumba',
#  'new norfolk',
#  'taolanaro',
#  'avera',
#  'upington',
#  'sharjah',
#  'aykhal',
#  'pingliang',
#  'moose factory',
#  'gambela',
#  'port alfred',
#  'wasserbillig',
#  'bilma',
#  'mount isa',
#  'avarua',
#  'saint-philippe',
#  'presidencia roque saenz pena',
#  'brae',
#  'vao',
#  'ostrovnoy',
#  'kavaratti',
#  'tallahassee',
#  'arauca',
#  'nikolskoye',
#  'mayor pablo lagerenza',
#  'samusu',
#  'margate',
#  'gizo',
#  'fortuna',
#  'dongsheng',
#  'bengkulu',
#  'trairi',
#  'pirapora',
#  'khatanga',
#  'illoqqortoormiut',
#  'cherskiy',
#  'jamestown',
#  'oussouye',
#  'talnakh',
#  'santa cruz',
#  'qabis',
#  'hay river',
#  'owando',
#  'aliwal north',
#  'chokurdakh',
#  'kulhudhuffushi',
#  'ahuimanu',
#  'belushya guba',
#  'kupang',
#  'fairbanks',
#  'lavrentiya',
#  'sarkand',
#  'souillac',
#  'hervey bay',
#  'pita',
#  'jiupu',
#  'tombouctou',
#  'puerto penasco',
#  'grand river south east',
#  'vaini',
#  'torbay',
#  'norman wells',
#  'hobart',
#  'impfondo',
#  'nizhneyansk',
#  'tambacounda',
#  'sao miguel do araguaia',
#  'baculin',
#  'ribeira grande',
#  'haines junction',
#  'disraeli',
#  'sambava',
#  'kaliua',
#  'buqayq',
#  'roebourne',
#  'opuwo',
#  'castro',
#  'east london',
#  'christchurch',
#  'yuzhno-yeniseyskiy',
#  'piranshahr',
#  'torbat-e jam',
#  'gweru',
#  'nechi',
#  'kieta',
#  'lazaro cardenas',
#  'iqaluit',
#  'coulihaut',
#  'bisalpur',
#  'byron bay',
#  'milkovo',
#  'manono',
#  'laredo',
#  'usinsk',
#  'samarai',
#  'hermanus',
#  'appleton',
#  'lorengau',
#  'tilichiki',
#  'amderma',
#  'ahipara',
#  'panguna',
#  'saskylakh',
#  'suifenhe',
#  'olafsvik',
#  'opobo',
#  'severo-kurilsk',
#  'kavieng',
#  'owensboro',
#  'moss vale',
#  'bend',
#  'krasnogorskoye',
#  'warqla',
#  'yanliang',
#  'kapit',
#  'salalah',
#  'coihaique',
#  'yellowknife',
#  'abnub',
#  'birao',
#  'long branch',
#  'ponta do sol',
#  'navoi',
#  'biak',
#  'areka',
#  'vilyuysk',
#  'coquimbo',
#  'quelimane',
#  'port hedland',
#  'marsh harbour',
#  'geraldton',
#  'vaitupu',
#  'halalo',
#  'pisco',
#  'san ramon de la nueva oran',
#  'yauya',
#  'mandali',
#  'isangel',
#  'kloulklubed',
#  'ullapool',
#  'mecca',
#  'lastoursville',
#  'provideniya',
#  'nanortalik',
#  'san nicolas',
#  'santa eulalia del rio',
#  'glenwood springs',
#  'oktyabrskoye',
#  'petrivka',
#  'zhigansk',
#  'dolores',
#  'santa rita',
#  'kalawit',
#  'upernavik',
#  'okhotsk',
#  'ugoofaaru',
#  'butaritari',
#  'cap malheureux',
#  'puerto leguizamo',
#  'cidreira',
#  'toora-khem',
#  'pangnirtung',
#  'wagga wagga',
#  'nadvoitsy',
#  'san patricio',
#  'qaqortoq',
#  'kruisfontein',
#  'attawapiskat',
#  'rawannawi',
#  'mana',
#  'limoeiro de anadia',
#  'kontagora',
#  'sargatskoye',
#  'puerto escondido',
#  'san cristobal',
#  'rizal',
#  'havre-saint-pierre',
#  'alotau',
#  'bara',
#  'merauke',
#  'yumen',
#  'najran',
#  'cortez',
#  'kununurra',
#  'nome',
#  'goderich',
#  'vidim',
#  'broken hill',
#  'bamut',
#  'yar-sale',
#  'qandahar',
#  'sao filipe',
#  'kurilsk',
#  'aflu',
#  'lerwick',
#  'kahului',
#  'arawa',
#  'celestun',
#  'lagoa',
#  'honningsvag',
#  'pella',
#  'cambyreta',
#  'berlevag',
#  'rosarito',
#  'palora',
#  'san carlos',
#  'mariakani',
#  'pacific grove',
#  'tiruchchendur',
#  'beringovskiy',
#  'saldanha',
#  'itarema',
#  'asau',
#  'codrington',
#  'cagayan de tawi-tawi',
#  'nioki',
#  'lompoc',
#  'mahaicony',
#  'pacifica',
#  'constitucion',
#  'chapais',
#  'nemuro',
#  'xuddur',
#  'jumla',
#  'hovd',
#  'saleaula',
#  'buraydah',
#  'alexandria',
#  'turangi',
#  'kaitangata',
#  'katsuura',
#  'sol-iletsk',
#  'zheleznodorozhnyy',
#  'vwawa',
#  'alofi',
#  'prince rupert',
#  'port lincoln',
#  'vanimo',
#  'mahina',
#  'sola',
#  'waipawa',
#  'grindavik',
#  'formoso do araguaia',
#  'mahebourg',
#  'deputatskiy',
#  'la ronge',
#  'port hardy',
#  'yabelo',
#  'half moon bay',
#  'mogadishu',
#  'wilmington',
#  'oktyabrskiy',
#  'helena',
#  'victoria',
#  'clearlake',
#  'bandarbeyla',
#  'labuhan',
#  'lingyuan',
#  'alto araguaia',
#  'whyalla',
#  'cayenne',
#  'necochea',
#  'anadyr',
#  'amurzet',
#  'lensk',
#  'tazovskiy',
#  'bela',
#  'hofn',
#  'balkanabat',
#  'juegang',
#  'matamoros',
#  'naryan-mar',
#  'panalingaan',
#  'bom jesus',
#  'lumberton',
#  'abu dhabi',
#  'perth',
#  'izhma',
#  'faya',
#  'lac-megantic',
#  'nassjo',
#  'millbrook',
#  'contamana',
#  'klaksvik',
#  'vestmanna',
#  'cotcot',
#  'palmas bellas',
#  'aden',
#  'atar',
#  'tecolutla',
#  'saint anthony',
#  'sao felix do xingu',
#  'nuuk',
#  'mys shmidta',
#  'kendari',
#  'ciudad bolivar',
#  'batagay-alyta',
#  'port blair',
#  'barao de melgaco',
#  'tsihombe',
#  'vila franca do campo',
#  'mandalgovi',
#  'zaida',
#  'san jose de rio tinto',
#  'ruatoria',
#  'galveston',
#  'verkhnevilyuysk',
#  'umzimvubu',
#  'karla',
#  'shetpe',
#  'aripuana',
#  'zhezkazgan',
#  'bodoco',
#  'aguimes',
#  'dien bien',
#  'tanda',
#  'chagda',
#  'mantua',
#  'sangre grande',
#  'petropavlovsk-kamchatskiy',
#  'taoudenni',
#  'kalanwali',
#  'kolyvan',
#  'adrar',
#  'canandaigua',
#  'ponnani',
#  'thompson',
#  'el campo',
#  'namie',
#  'mlalo',
#  'ijaki',
#  'gramoteino',
#  'ewa beach',
#  'lebu',
#  'port moresby',
#  'egvekinot',
#  'guerrero negro',
#  'quimper',
#  'faanui',
#  'ilulissat',
#  'pangody',
#  'garissa',
#  'aksha',
#  'sinnamary',
#  'baykit',
#  'tuatapere',
#  'southbridge',
#  'caucaia',
#  'manyana',
#  'manaus',
#  'tuktoyaktuk',
#  'tanout',
#  'beloha',
#  'atambua',
#  'comodoro rivadavia',
#  'llanes',
#  'orlik',
#  'suao',
#  'rungata',
#  'aswan',
#  'hamilton',
#  'nsoko',
#  'lamu',
#  'cedartown',
#  'tarkwa',
#  'kampot',
#  'maiduguri',
#  'tignoan',
#  'havoysund',
#  'seddon',
#  'kamenka',
#  'umm kaddadah',
#  'kebumen',
#  'agua branca',
#  'strathpeffer',
#  'nouakchott',
#  'arlit',
#  'kyabram',
#  'marcona',
#  'verdalsora',
#  'teya',
#  'luba',
#  'dzilam gonzalez',
#  'manzhouli',
#  'suna',
#  'balaipungut',
#  'inongo',
#  'linqiong',
#  'xai-xai',
#  'lillooet',
#  'safwah',
#  'baruun-urt',
#  'nueve de julio',
#  'ukiah',
#  'benghazi',
#  'makakilo city',
#  'mondlo',
#  'ashqelon',
#  'meulaboh',
#  'nosy varika',
#  'sao joao del rei',
#  'serowe',
#  'aquiraz',
#  'yulara',
#  'komsomolskiy',
#  'miercurea sibiului',
#  'palizada',
#  'bambanglipuro',
#  'dire',
#  'viedma',
#  'novokayakent',
#  'tailai',
#  'seoul',
#  'goma',
#  'mocambique',
#  'weiser',
#  'daru',
#  'santiago de cao',
#  'ayagoz',
#  'shagonar',
#  'the valley',
#  'dovers',
#  'buon me thuot',
#  'gweta',
#  'guantanamo',
#  'praya',
#  'mahadday weyne',
#  'mattru',
#  'kosice',
#  'shumikha',
#  'haimen',
#  'mabaruma',
#  'bayan',
#  'areia branca',
#  'lamesa',
#  'brandon',
#  'elliot',
#  'soloneshnoye',
#  'pemangkat',
#  'poum',
#  'jalu',
#  'chipinge',
#  'wajir',
#  'huarmey',
#  'osa',
#  'mahibadhoo',
#  'lomintsevskiy',
#  'dudinka',
#  'mehran',
#  'bereda',
#  'marawi',
#  'lubango',
#  'bagdarin',
#  'ayapa',
#  'palana',
#  'lima',
#  'saint-joseph',
#  'chumikan',
#  'beibei',
#  'tukrah',
#  'mrirt',
#  'saint-augustin',
#  'esperance',
#  'mehriz',
#  'barcelona',
#  'novyy urengoy',
#  'radhanpur',
#  'namatanai',
#  'albanel',
#  'tessalit',
#  'sibu',
#  'erhlin',
#  'exu',
#  'pavlovka',
#  'shimoda',
#  'shelton',
#  'sitka',
#  'kargat',
#  'los llanos de aridane',
#  'anori',
#  'san quintin',
#  'zhuanghe',
#  'sugag',
#  'batagay',
#  'marienburg',
#  'trincomalee',
#  'carutapera',
#  'fairview',
#  'koumac',
#  'boguszow-gorce',
#  'kargopol',
#  'imatra',
#  'nicoya',
#  'tiksi',
#  'kapuskasing',
#  'diamantino',
#  'mizdah',
#  'gazanjyk',
#  'malwan',
#  'ormara',
#  'concepcion',
#  'kushima',
#  'kpandae',
#  'sabang',
#  'iracoubo',
#  'olot',
#  'novyy urgal',
#  'tabukiniberu',
#  'surt',
#  'ngukurr',
#  'imelda',
#  'kalmunai',
#  'hakui',
#  'aviles',
#  'peikang',
#  'cervo',
#  'sayat',
#  'nevsehir',
#  'oistins',
#  'arys',
#  'bratislava',
#  'kirov',
#  'mogok',
#  'tabulbah',
#  'kaili',
#  'popondetta',
#  'lakselv',
#  'wadhwan',
#  'placido de castro',
#  'greenville',
#  'thyboron',
#  'santa marta',
#  'laguna',
#  'jackson',
#  'padang',
#  'murray bridge',
#  'bonfim',
#  'rawson',
#  'kholmogory',
#  'karwar',
#  'dargaville',
#  'gobo',
#  'flinders',
#  'burns lake',
#  'henties bay',
#  'dom pedro',
#  'khandyga',
#  'vardo',
#  'dawlatabad',
#  'ittiri',
#  'puerto narino',
#  'yeysk',
#  'bolungarvik',
#  'paciran',
#  'manzil tamim',
#  'beira',
#  'stavern',
#  'misrikh',
#  'djibo',
#  'takhtamukay',
#  'husavik',
#  'beyneu',
#  'quatre cocos',
#  'erzurum',
#  'riachao do jacuipe',
#  'liezen',
#  'zabol',
#  'leh',
#  'irece',
#  'san lorenzo',
#  'chipurupalle',
#  'palatka',
#  'juneau',
#  'tumarbong',
#  'astana',
#  'lichuan',
#  'angoche',
#  'rio gallegos',
#  'la macarena',
#  'encruzilhada do sul',
#  'yamada',
#  'nalut',
#  'amahai',
#  'yinchuan',
#  'denpasar',
#  'yerofey pavlovich',
#  'hirara',
#  'gazli',
#  'sokolo',
#  'sakakah',
#  'barawe',
#  'champerico',
#  'deniliquin',
#  'guanica',
#  'tuy hoa',
#  'ancud',
#  'turukhansk',
#  'hobyo',
#  'nchelenge',
#  'severo-yeniseyskiy',
#  'mandan',
#  'palabuhanratu',
#  'oranjemund',
#  'safaqis',
#  'touros',
#  'pasighat',
#  'loreto',
#  'ulladulla',
#  'pirganj',
#  'yefimovskiy',
#  'bilibino',
#  'lhokseumawe',
#  'eydhafushi',
#  'ixtapa',
#  'ust-shonosha',
#  'natal',
#  'shillong',
#  'hun',
#  'karaul',
#  'kihei',
#  'berezovka',
#  'auki',
#  'garachine',
#  'karratha',
#  'bolshaya rechka',
#  'rudnya',
#  'floro',
#  'singkang',
#  'qasigiannguit',
#  'la paz',
#  'gornopravdinsk',
#  'askiz',
#  'boda',
#  'muli',
#  'springbok',
#  'sobolevo',
#  'panama city',
#  'luau',
#  'ursulo galvan',
#  'sechura',
#  'reinosa',
#  'sharlyk',
#  'brownsville',
#  'batticaloa',
#  'camana',
#  'kerman',
#  'hokitika',
#  'teluk nibung',
#  'matara',
#  'grand-lahou',
#  'visnes',
#  'trelew',
#  'vagay',
#  'mokhsogollokh',
#  'nyurba',
#  'te anau',
#  'caravelas',
#  'richards bay',
#  'sungurlu',
#  'zhangye',
#  'outjo',
#  'hohhot',
#  'mujiayingzi',
#  'srandakan',
#  'piacabucu',
#  'manhattan',
#  'puerto madero',
#  'karkaralinsk',
#  'itanhem',
#  'nago',
#  'veraval',
#  'bargal',
#  'eastbourne']

# %%
# Perform an API call with the OpenWeatherMap.
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        
        # Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "q=" + cities[i] + "&appid=" + weather_api_key + "&units=imperial"
       
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["main"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        # Weather description (for example, clouds, fog, light rain, clear sky)
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bambous virieux
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | nioro
# Processing Record 4 of Set 1 | aksu
# Processing Record 5 of Set 1 | cabo san lucas
# Processing Record 6 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 1 | ambon
# Processing Record 8 of Set 1 | pevek
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | emerald
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | paamiut
# Processing Record 18 of Set 1 | bubaque
# Processing Record 19 of Set 1 | kerki
# City not found. Skipping...
# Processing Record 20 of Set 1 | tortoli
# Processing Record 21 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | mount gambier
# Processing Record 24 of Set 1 | gat
# Processing Record 25 of Set 1 | longyearbyen
# Processing Record 26 of Set 1 | kautokeino
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | narsaq
# Processing Record 29 of Set 1 | shingu
# Processing Record 30 of Set 1 | gamba
# Processing Record 31 of Set 1 | vestmannaeyjar
# Processing Record 32 of Set 1 | roald
# Processing Record 33 of Set 1 | sumbe
# Processing Record 34 of Set 1 | luderitz
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | muroto
# Processing Record 40 of Set 1 | santa rosalia
# Processing Record 41 of Set 1 | sabzevar
# Processing Record 42 of Set 1 | allapalli
# Processing Record 43 of Set 1 | turayf
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | marsaxlokk
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | araouane
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | portland
# Processing Record 2 of Set 2 | cockburn town
# Processing Record 3 of Set 2 | kapoeta
# Processing Record 4 of Set 2 | leningradskiy
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | ornskoldsvik
# Processing Record 7 of Set 2 | lata
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | njombe
# Processing Record 10 of Set 2 | palmer
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | hasaki
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | yevlax
# Processing Record 16 of Set 2 | sao joao da barra
# Processing Record 17 of Set 2 | pokaran
# Processing Record 18 of Set 2 | malumfashi
# Processing Record 19 of Set 2 | airai
# Processing Record 20 of Set 2 | kuala krai
# City not found. Skipping...
# Processing Record 21 of Set 2 | altamira
# Processing Record 22 of Set 2 | eenhana
# Processing Record 23 of Set 2 | kutum
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | nanzhang
# Processing Record 26 of Set 2 | roros
# Processing Record 27 of Set 2 | andenes
# Processing Record 28 of Set 2 | aklavik
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | cabedelo
# Processing Record 31 of Set 2 | lakatoro
# Processing Record 32 of Set 2 | saint-pierre
# Processing Record 33 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | marathon
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | kapaa
# Processing Record 39 of Set 2 | mayumba
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 2 | avera
# Processing Record 43 of Set 2 | upington
# Processing Record 44 of Set 2 | sharjah
# Processing Record 45 of Set 2 | aykhal
# Processing Record 46 of Set 2 | pingliang
# Processing Record 47 of Set 2 | moose factory
# Processing Record 48 of Set 2 | gambela
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | wasserbillig
# Processing Record 1 of Set 3 | bilma
# Processing Record 2 of Set 3 | mount isa
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | presidencia roque saenz pena
# Processing Record 6 of Set 3 | brae
# Processing Record 7 of Set 3 | vao
# Processing Record 8 of Set 3 | ostrovnoy
# Processing Record 9 of Set 3 | kavaratti
# Processing Record 10 of Set 3 | tallahassee
# Processing Record 11 of Set 3 | arauca
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | mayor pablo lagerenza
# Processing Record 14 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 3 | margate
# Processing Record 16 of Set 3 | gizo
# Processing Record 17 of Set 3 | fortuna
# Processing Record 18 of Set 3 | dongsheng
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | trairi
# Processing Record 21 of Set 3 | pirapora
# Processing Record 22 of Set 3 | khatanga
# Processing Record 23 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 3 | cherskiy
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | oussouye
# Processing Record 27 of Set 3 | talnakh
# Processing Record 28 of Set 3 | santa cruz
# Processing Record 29 of Set 3 | qabis
# City not found. Skipping...
# Processing Record 30 of Set 3 | hay river
# Processing Record 31 of Set 3 | owando
# Processing Record 32 of Set 3 | aliwal north
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | kulhudhuffushi
# Processing Record 35 of Set 3 | ahuimanu
# Processing Record 36 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 3 | kupang
# Processing Record 38 of Set 3 | fairbanks
# Processing Record 39 of Set 3 | lavrentiya
# Processing Record 40 of Set 3 | sarkand
# Processing Record 41 of Set 3 | souillac
# Processing Record 42 of Set 3 | hervey bay
# Processing Record 43 of Set 3 | pita
# Processing Record 44 of Set 3 | jiupu
# Processing Record 45 of Set 3 | tombouctou
# Processing Record 46 of Set 3 | puerto penasco
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 3 | vaini
# Processing Record 49 of Set 3 | torbay
# Processing Record 50 of Set 3 | norman wells
# Processing Record 1 of Set 4 | hobart
# Processing Record 2 of Set 4 | impfondo
# Processing Record 3 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 4 | tambacounda
# Processing Record 5 of Set 4 | sao miguel do araguaia
# Processing Record 6 of Set 4 | baculin
# Processing Record 7 of Set 4 | ribeira grande
# Processing Record 8 of Set 4 | haines junction
# Processing Record 9 of Set 4 | disraeli
# Processing Record 10 of Set 4 | sambava
# Processing Record 11 of Set 4 | kaliua
# Processing Record 12 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 13 of Set 4 | roebourne
# Processing Record 14 of Set 4 | opuwo
# Processing Record 15 of Set 4 | castro
# Processing Record 16 of Set 4 | east london
# Processing Record 17 of Set 4 | christchurch
# Processing Record 18 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 19 of Set 4 | piranshahr
# Processing Record 20 of Set 4 | torbat-e jam
# Processing Record 21 of Set 4 | gweru
# Processing Record 22 of Set 4 | nechi
# Processing Record 23 of Set 4 | kieta
# Processing Record 24 of Set 4 | lazaro cardenas
# Processing Record 25 of Set 4 | iqaluit
# Processing Record 26 of Set 4 | coulihaut
# City not found. Skipping...
# Processing Record 27 of Set 4 | bisalpur
# Processing Record 28 of Set 4 | byron bay
# Processing Record 29 of Set 4 | milkovo
# Processing Record 30 of Set 4 | manono
# Processing Record 31 of Set 4 | laredo
# Processing Record 32 of Set 4 | usinsk
# Processing Record 33 of Set 4 | samarai
# Processing Record 34 of Set 4 | hermanus
# Processing Record 35 of Set 4 | appleton
# Processing Record 36 of Set 4 | lorengau
# Processing Record 37 of Set 4 | tilichiki
# Processing Record 38 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 4 | ahipara
# Processing Record 40 of Set 4 | panguna
# Processing Record 41 of Set 4 | saskylakh
# Processing Record 42 of Set 4 | suifenhe
# Processing Record 43 of Set 4 | olafsvik
# Processing Record 44 of Set 4 | opobo
# City not found. Skipping...
# Processing Record 45 of Set 4 | severo-kurilsk
# Processing Record 46 of Set 4 | kavieng
# Processing Record 47 of Set 4 | owensboro
# Processing Record 48 of Set 4 | moss vale
# Processing Record 49 of Set 4 | bend
# Processing Record 50 of Set 4 | krasnogorskoye
# Processing Record 1 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 5 | yanliang
# Processing Record 3 of Set 5 | kapit
# Processing Record 4 of Set 5 | salalah
# Processing Record 5 of Set 5 | coihaique
# Processing Record 6 of Set 5 | yellowknife
# Processing Record 7 of Set 5 | abnub
# Processing Record 8 of Set 5 | birao
# Processing Record 9 of Set 5 | long branch
# Processing Record 10 of Set 5 | ponta do sol
# Processing Record 11 of Set 5 | navoi
# Processing Record 12 of Set 5 | biak
# Processing Record 13 of Set 5 | areka
# Processing Record 14 of Set 5 | vilyuysk
# Processing Record 15 of Set 5 | coquimbo
# Processing Record 16 of Set 5 | quelimane
# Processing Record 17 of Set 5 | port hedland
# Processing Record 18 of Set 5 | marsh harbour
# Processing Record 19 of Set 5 | geraldton
# Processing Record 20 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 5 | pisco
# Processing Record 23 of Set 5 | san ramon de la nueva oran
# Processing Record 24 of Set 5 | yauya
# Processing Record 25 of Set 5 | mandali
# Processing Record 26 of Set 5 | isangel
# Processing Record 27 of Set 5 | kloulklubed
# Processing Record 28 of Set 5 | ullapool
# Processing Record 29 of Set 5 | mecca
# Processing Record 30 of Set 5 | lastoursville
# Processing Record 31 of Set 5 | provideniya
# Processing Record 32 of Set 5 | nanortalik
# Processing Record 33 of Set 5 | san nicolas
# Processing Record 34 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 35 of Set 5 | glenwood springs
# Processing Record 36 of Set 5 | oktyabrskoye
# Processing Record 37 of Set 5 | petrivka
# Processing Record 38 of Set 5 | zhigansk
# Processing Record 39 of Set 5 | dolores
# Processing Record 40 of Set 5 | santa rita
# Processing Record 41 of Set 5 | kalawit
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | okhotsk
# Processing Record 44 of Set 5 | ugoofaaru
# Processing Record 45 of Set 5 | butaritari
# Processing Record 46 of Set 5 | cap malheureux
# Processing Record 47 of Set 5 | puerto leguizamo
# Processing Record 48 of Set 5 | cidreira
# Processing Record 49 of Set 5 | toora-khem
# Processing Record 50 of Set 5 | pangnirtung
# Processing Record 1 of Set 6 | wagga wagga
# Processing Record 2 of Set 6 | nadvoitsy
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | qaqortoq
# Processing Record 5 of Set 6 | kruisfontein
# Processing Record 6 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 6 | mana
# Processing Record 9 of Set 6 | limoeiro de anadia
# Processing Record 10 of Set 6 | kontagora
# Processing Record 11 of Set 6 | sargatskoye
# Processing Record 12 of Set 6 | puerto escondido
# Processing Record 13 of Set 6 | san cristobal
# Processing Record 14 of Set 6 | rizal
# Processing Record 15 of Set 6 | havre-saint-pierre
# Processing Record 16 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 6 | bara
# Processing Record 18 of Set 6 | merauke
# Processing Record 19 of Set 6 | yumen
# Processing Record 20 of Set 6 | najran
# Processing Record 21 of Set 6 | cortez
# Processing Record 22 of Set 6 | kununurra
# Processing Record 23 of Set 6 | nome
# Processing Record 24 of Set 6 | goderich
# Processing Record 25 of Set 6 | vidim
# Processing Record 26 of Set 6 | broken hill
# Processing Record 27 of Set 6 | bamut
# Processing Record 28 of Set 6 | yar-sale
# Processing Record 29 of Set 6 | qandahar
# City not found. Skipping...
# Processing Record 30 of Set 6 | sao filipe
# Processing Record 31 of Set 6 | kurilsk
# Processing Record 32 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 6 | lerwick
# Processing Record 34 of Set 6 | kahului
# Processing Record 35 of Set 6 | arawa
# Processing Record 36 of Set 6 | celestun
# Processing Record 37 of Set 6 | lagoa
# Processing Record 38 of Set 6 | honningsvag
# Processing Record 39 of Set 6 | pella
# Processing Record 40 of Set 6 | cambyreta
# City not found. Skipping...
# Processing Record 41 of Set 6 | berlevag
# Processing Record 42 of Set 6 | rosarito
# Processing Record 43 of Set 6 | palora
# Processing Record 44 of Set 6 | san carlos
# Processing Record 45 of Set 6 | mariakani
# Processing Record 46 of Set 6 | pacific grove
# Processing Record 47 of Set 6 | tiruchchendur
# Processing Record 48 of Set 6 | beringovskiy
# Processing Record 49 of Set 6 | saldanha
# Processing Record 50 of Set 6 | itarema
# Processing Record 1 of Set 7 | asau
# Processing Record 2 of Set 7 | codrington
# Processing Record 3 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 4 of Set 7 | nioki
# Processing Record 5 of Set 7 | lompoc
# Processing Record 6 of Set 7 | mahaicony
# City not found. Skipping...
# Processing Record 7 of Set 7 | pacifica
# Processing Record 8 of Set 7 | constitucion
# Processing Record 9 of Set 7 | chapais
# Processing Record 10 of Set 7 | nemuro
# Processing Record 11 of Set 7 | xuddur
# Processing Record 12 of Set 7 | jumla
# Processing Record 13 of Set 7 | hovd
# Processing Record 14 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 7 | buraydah
# Processing Record 16 of Set 7 | alexandria
# Processing Record 17 of Set 7 | turangi
# Processing Record 18 of Set 7 | kaitangata
# Processing Record 19 of Set 7 | katsuura
# Processing Record 20 of Set 7 | sol-iletsk
# Processing Record 21 of Set 7 | zheleznodorozhnyy
# Processing Record 22 of Set 7 | vwawa
# Processing Record 23 of Set 7 | alofi
# Processing Record 24 of Set 7 | prince rupert
# Processing Record 25 of Set 7 | port lincoln
# Processing Record 26 of Set 7 | vanimo
# Processing Record 27 of Set 7 | mahina
# Processing Record 28 of Set 7 | sola
# Processing Record 29 of Set 7 | waipawa
# Processing Record 30 of Set 7 | grindavik
# Processing Record 31 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 32 of Set 7 | mahebourg
# Processing Record 33 of Set 7 | deputatskiy
# Processing Record 34 of Set 7 | la ronge
# Processing Record 35 of Set 7 | port hardy
# Processing Record 36 of Set 7 | yabelo
# Processing Record 37 of Set 7 | half moon bay
# Processing Record 38 of Set 7 | mogadishu
# Processing Record 39 of Set 7 | wilmington
# Processing Record 40 of Set 7 | oktyabrskiy
# Processing Record 41 of Set 7 | helena
# Processing Record 42 of Set 7 | victoria
# Processing Record 43 of Set 7 | clearlake
# Processing Record 44 of Set 7 | bandarbeyla
# Processing Record 45 of Set 7 | labuhan
# Processing Record 46 of Set 7 | lingyuan
# Processing Record 47 of Set 7 | alto araguaia
# Processing Record 48 of Set 7 | whyalla
# Processing Record 49 of Set 7 | cayenne
# Processing Record 50 of Set 7 | necochea
# Processing Record 1 of Set 8 | anadyr
# Processing Record 2 of Set 8 | amurzet
# Processing Record 3 of Set 8 | lensk
# Processing Record 4 of Set 8 | tazovskiy
# Processing Record 5 of Set 8 | bela
# Processing Record 6 of Set 8 | hofn
# Processing Record 7 of Set 8 | balkanabat
# Processing Record 8 of Set 8 | juegang
# Processing Record 9 of Set 8 | matamoros
# Processing Record 10 of Set 8 | naryan-mar
# Processing Record 11 of Set 8 | panalingaan
# Processing Record 12 of Set 8 | bom jesus
# Processing Record 13 of Set 8 | lumberton
# Processing Record 14 of Set 8 | abu dhabi
# Processing Record 15 of Set 8 | perth
# Processing Record 16 of Set 8 | izhma
# Processing Record 17 of Set 8 | faya
# Processing Record 18 of Set 8 | lac-megantic
# Processing Record 19 of Set 8 | nassjo
# Processing Record 20 of Set 8 | millbrook
# Processing Record 21 of Set 8 | contamana
# Processing Record 22 of Set 8 | klaksvik
# Processing Record 23 of Set 8 | vestmanna
# Processing Record 24 of Set 8 | cotcot
# Processing Record 25 of Set 8 | palmas bellas
# Processing Record 26 of Set 8 | aden
# Processing Record 27 of Set 8 | atar
# Processing Record 28 of Set 8 | tecolutla
# Processing Record 29 of Set 8 | saint anthony
# Processing Record 30 of Set 8 | sao felix do xingu
# Processing Record 31 of Set 8 | nuuk
# Processing Record 32 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 8 | kendari
# Processing Record 34 of Set 8 | ciudad bolivar
# Processing Record 35 of Set 8 | batagay-alyta
# Processing Record 36 of Set 8 | port blair
# Processing Record 37 of Set 8 | barao de melgaco
# Processing Record 38 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 8 | vila franca do campo
# Processing Record 40 of Set 8 | mandalgovi
# Processing Record 41 of Set 8 | zaida
# Processing Record 42 of Set 8 | san jose de rio tinto
# Processing Record 43 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 8 | galveston
# Processing Record 45 of Set 8 | verkhnevilyuysk
# Processing Record 46 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 8 | karla
# Processing Record 48 of Set 8 | shetpe
# Processing Record 49 of Set 8 | aripuana
# Processing Record 50 of Set 8 | zhezkazgan
# Processing Record 1 of Set 9 | bodoco
# City not found. Skipping...
# Processing Record 2 of Set 9 | aguimes
# Processing Record 3 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 4 of Set 9 | tanda
# Processing Record 5 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 9 | mantua
# Processing Record 7 of Set 9 | sangre grande
# Processing Record 8 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 9 | taoudenni
# Processing Record 10 of Set 9 | kalanwali
# Processing Record 11 of Set 9 | kolyvan
# Processing Record 12 of Set 9 | adrar
# Processing Record 13 of Set 9 | canandaigua
# Processing Record 14 of Set 9 | ponnani
# Processing Record 15 of Set 9 | thompson
# Processing Record 16 of Set 9 | el campo
# Processing Record 17 of Set 9 | namie
# Processing Record 18 of Set 9 | mlalo
# Processing Record 19 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 20 of Set 9 | gramoteino
# Processing Record 21 of Set 9 | ewa beach
# Processing Record 22 of Set 9 | lebu
# Processing Record 23 of Set 9 | port moresby
# Processing Record 24 of Set 9 | egvekinot
# Processing Record 25 of Set 9 | guerrero negro
# Processing Record 26 of Set 9 | quimper
# Processing Record 27 of Set 9 | faanui
# Processing Record 28 of Set 9 | ilulissat
# Processing Record 29 of Set 9 | pangody
# Processing Record 30 of Set 9 | garissa
# Processing Record 31 of Set 9 | aksha
# Processing Record 32 of Set 9 | sinnamary
# Processing Record 33 of Set 9 | baykit
# Processing Record 34 of Set 9 | tuatapere
# Processing Record 35 of Set 9 | southbridge
# Processing Record 36 of Set 9 | caucaia
# Processing Record 37 of Set 9 | manyana
# Processing Record 38 of Set 9 | manaus
# Processing Record 39 of Set 9 | tuktoyaktuk
# Processing Record 40 of Set 9 | tanout
# Processing Record 41 of Set 9 | beloha
# Processing Record 42 of Set 9 | atambua
# Processing Record 43 of Set 9 | comodoro rivadavia
# Processing Record 44 of Set 9 | llanes
# Processing Record 45 of Set 9 | orlik
# Processing Record 46 of Set 9 | suao
# City not found. Skipping...
# Processing Record 47 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 9 | aswan
# Processing Record 49 of Set 9 | hamilton
# Processing Record 50 of Set 9 | nsoko
# Processing Record 1 of Set 10 | lamu
# Processing Record 2 of Set 10 | cedartown
# Processing Record 3 of Set 10 | tarkwa
# Processing Record 4 of Set 10 | kampot
# Processing Record 5 of Set 10 | maiduguri
# Processing Record 6 of Set 10 | tignoan
# Processing Record 7 of Set 10 | havoysund
# Processing Record 8 of Set 10 | seddon
# Processing Record 9 of Set 10 | kamenka
# Processing Record 10 of Set 10 | umm kaddadah
# Processing Record 11 of Set 10 | kebumen
# Processing Record 12 of Set 10 | agua branca
# Processing Record 13 of Set 10 | strathpeffer
# Processing Record 14 of Set 10 | nouakchott
# Processing Record 15 of Set 10 | arlit
# Processing Record 16 of Set 10 | kyabram
# Processing Record 17 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 10 | verdalsora
# City not found. Skipping...
# Processing Record 19 of Set 10 | teya
# Processing Record 20 of Set 10 | luba
# Processing Record 21 of Set 10 | dzilam gonzalez
# Processing Record 22 of Set 10 | manzhouli
# Processing Record 23 of Set 10 | suna
# Processing Record 24 of Set 10 | balaipungut
# Processing Record 25 of Set 10 | inongo
# Processing Record 26 of Set 10 | linqiong
# Processing Record 27 of Set 10 | xai-xai
# Processing Record 28 of Set 10 | lillooet
# Processing Record 29 of Set 10 | safwah
# City not found. Skipping...
# Processing Record 30 of Set 10 | baruun-urt
# Processing Record 31 of Set 10 | nueve de julio
# Processing Record 32 of Set 10 | ukiah
# Processing Record 33 of Set 10 | benghazi
# Processing Record 34 of Set 10 | makakilo city
# Processing Record 35 of Set 10 | mondlo
# Processing Record 36 of Set 10 | ashqelon
# Processing Record 37 of Set 10 | meulaboh
# Processing Record 38 of Set 10 | nosy varika
# Processing Record 39 of Set 10 | sao joao del rei
# Processing Record 40 of Set 10 | serowe
# Processing Record 41 of Set 10 | aquiraz
# Processing Record 42 of Set 10 | yulara
# Processing Record 43 of Set 10 | komsomolskiy
# Processing Record 44 of Set 10 | miercurea sibiului
# Processing Record 45 of Set 10 | palizada
# Processing Record 46 of Set 10 | bambanglipuro
# Processing Record 47 of Set 10 | dire
# Processing Record 48 of Set 10 | viedma
# Processing Record 49 of Set 10 | novokayakent
# Processing Record 50 of Set 10 | tailai
# Processing Record 1 of Set 11 | seoul
# Processing Record 2 of Set 11 | goma
# Processing Record 3 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 4 of Set 11 | weiser
# Processing Record 5 of Set 11 | daru
# Processing Record 6 of Set 11 | santiago de cao
# Processing Record 7 of Set 11 | ayagoz
# Processing Record 8 of Set 11 | shagonar
# Processing Record 9 of Set 11 | the valley
# Processing Record 10 of Set 11 | dovers
# Processing Record 11 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 12 of Set 11 | gweta
# Processing Record 13 of Set 11 | guantanamo
# Processing Record 14 of Set 11 | praya
# Processing Record 15 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 16 of Set 11 | mattru
# Processing Record 17 of Set 11 | kosice
# Processing Record 18 of Set 11 | shumikha
# Processing Record 19 of Set 11 | haimen
# Processing Record 20 of Set 11 | mabaruma
# Processing Record 21 of Set 11 | bayan
# Processing Record 22 of Set 11 | areia branca
# Processing Record 23 of Set 11 | lamesa
# Processing Record 24 of Set 11 | brandon
# Processing Record 25 of Set 11 | elliot
# Processing Record 26 of Set 11 | soloneshnoye
# Processing Record 27 of Set 11 | pemangkat
# Processing Record 28 of Set 11 | poum
# Processing Record 29 of Set 11 | jalu
# Processing Record 30 of Set 11 | chipinge
# Processing Record 31 of Set 11 | wajir
# Processing Record 32 of Set 11 | huarmey
# Processing Record 33 of Set 11 | osa
# Processing Record 34 of Set 11 | mahibadhoo
# Processing Record 35 of Set 11 | lomintsevskiy
# Processing Record 36 of Set 11 | dudinka
# Processing Record 37 of Set 11 | mehran
# Processing Record 38 of Set 11 | bereda
# Processing Record 39 of Set 11 | marawi
# Processing Record 40 of Set 11 | lubango
# Processing Record 41 of Set 11 | bagdarin
# Processing Record 42 of Set 11 | ayapa
# Processing Record 43 of Set 11 | palana
# Processing Record 44 of Set 11 | lima
# Processing Record 45 of Set 11 | saint-joseph
# Processing Record 46 of Set 11 | chumikan
# Processing Record 47 of Set 11 | beibei
# Processing Record 48 of Set 11 | tukrah
# Processing Record 49 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 11 | saint-augustin
# Processing Record 1 of Set 12 | esperance
# Processing Record 2 of Set 12 | mehriz
# Processing Record 3 of Set 12 | barcelona
# Processing Record 4 of Set 12 | novyy urengoy
# Processing Record 5 of Set 12 | radhanpur
# Processing Record 6 of Set 12 | namatanai
# Processing Record 7 of Set 12 | albanel
# Processing Record 8 of Set 12 | tessalit
# Processing Record 9 of Set 12 | sibu
# Processing Record 10 of Set 12 | erhlin
# City not found. Skipping...
# Processing Record 11 of Set 12 | exu
# Processing Record 12 of Set 12 | pavlovka
# Processing Record 13 of Set 12 | shimoda
# Processing Record 14 of Set 12 | shelton
# Processing Record 15 of Set 12 | sitka
# Processing Record 16 of Set 12 | kargat
# Processing Record 17 of Set 12 | los llanos de aridane
# Processing Record 18 of Set 12 | anori
# Processing Record 19 of Set 12 | san quintin
# Processing Record 20 of Set 12 | zhuanghe
# Processing Record 21 of Set 12 | sugag
# Processing Record 22 of Set 12 | batagay
# Processing Record 23 of Set 12 | marienburg
# Processing Record 24 of Set 12 | trincomalee
# Processing Record 25 of Set 12 | carutapera
# Processing Record 26 of Set 12 | fairview
# Processing Record 27 of Set 12 | koumac
# Processing Record 28 of Set 12 | boguszow-gorce
# Processing Record 29 of Set 12 | kargopol
# Processing Record 30 of Set 12 | imatra
# Processing Record 31 of Set 12 | nicoya
# Processing Record 32 of Set 12 | tiksi
# Processing Record 33 of Set 12 | kapuskasing
# Processing Record 34 of Set 12 | diamantino
# Processing Record 35 of Set 12 | mizdah
# Processing Record 36 of Set 12 | gazanjyk
# Processing Record 37 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 12 | ormara
# Processing Record 39 of Set 12 | concepcion
# Processing Record 40 of Set 12 | kushima
# Processing Record 41 of Set 12 | kpandae
# Processing Record 42 of Set 12 | sabang
# Processing Record 43 of Set 12 | iracoubo
# Processing Record 44 of Set 12 | olot
# Processing Record 45 of Set 12 | novyy urgal
# Processing Record 46 of Set 12 | tabukiniberu
# City not found. Skipping...
# Processing Record 47 of Set 12 | surt
# Processing Record 48 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 12 | imelda
# Processing Record 50 of Set 12 | kalmunai
# Processing Record 1 of Set 13 | hakui
# Processing Record 2 of Set 13 | aviles
# Processing Record 3 of Set 13 | peikang
# City not found. Skipping...
# Processing Record 4 of Set 13 | cervo
# Processing Record 5 of Set 13 | sayat
# Processing Record 6 of Set 13 | nevsehir
# Processing Record 7 of Set 13 | oistins
# Processing Record 8 of Set 13 | arys
# Processing Record 9 of Set 13 | bratislava
# Processing Record 10 of Set 13 | kirov
# Processing Record 11 of Set 13 | mogok
# Processing Record 12 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 13 of Set 13 | kaili
# Processing Record 14 of Set 13 | popondetta
# Processing Record 15 of Set 13 | lakselv
# Processing Record 16 of Set 13 | wadhwan
# City not found. Skipping...
# Processing Record 17 of Set 13 | placido de castro
# Processing Record 18 of Set 13 | greenville
# Processing Record 19 of Set 13 | thyboron
# Processing Record 20 of Set 13 | santa marta
# Processing Record 21 of Set 13 | laguna
# Processing Record 22 of Set 13 | jackson
# Processing Record 23 of Set 13 | padang
# Processing Record 24 of Set 13 | murray bridge
# Processing Record 25 of Set 13 | bonfim
# Processing Record 26 of Set 13 | rawson
# Processing Record 27 of Set 13 | kholmogory
# Processing Record 28 of Set 13 | karwar
# Processing Record 29 of Set 13 | dargaville
# Processing Record 30 of Set 13 | gobo
# Processing Record 31 of Set 13 | flinders
# Processing Record 32 of Set 13 | burns lake
# Processing Record 33 of Set 13 | henties bay
# Processing Record 34 of Set 13 | dom pedro
# Processing Record 35 of Set 13 | khandyga
# Processing Record 36 of Set 13 | vardo
# Processing Record 37 of Set 13 | dawlatabad
# Processing Record 38 of Set 13 | ittiri
# Processing Record 39 of Set 13 | puerto narino
# Processing Record 40 of Set 13 | yeysk
# Processing Record 41 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 13 | paciran
# Processing Record 43 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 44 of Set 13 | beira
# Processing Record 45 of Set 13 | stavern
# Processing Record 46 of Set 13 | misrikh
# Processing Record 47 of Set 13 | djibo
# Processing Record 48 of Set 13 | takhtamukay
# Processing Record 49 of Set 13 | husavik
# Processing Record 50 of Set 13 | beyneu
# Processing Record 1 of Set 14 | quatre cocos
# Processing Record 2 of Set 14 | erzurum
# Processing Record 3 of Set 14 | riachao do jacuipe
# Processing Record 4 of Set 14 | liezen
# Processing Record 5 of Set 14 | zabol
# Processing Record 6 of Set 14 | leh
# Processing Record 7 of Set 14 | irece
# Processing Record 8 of Set 14 | san lorenzo
# Processing Record 9 of Set 14 | chipurupalle
# Processing Record 10 of Set 14 | palatka
# Processing Record 11 of Set 14 | juneau
# Processing Record 12 of Set 14 | tumarbong
# Processing Record 13 of Set 14 | astana
# Processing Record 14 of Set 14 | lichuan
# Processing Record 15 of Set 14 | angoche
# Processing Record 16 of Set 14 | rio gallegos
# Processing Record 17 of Set 14 | la macarena
# Processing Record 18 of Set 14 | encruzilhada do sul
# Processing Record 19 of Set 14 | yamada
# Processing Record 20 of Set 14 | nalut
# Processing Record 21 of Set 14 | amahai
# Processing Record 22 of Set 14 | yinchuan
# Processing Record 23 of Set 14 | denpasar
# Processing Record 24 of Set 14 | yerofey pavlovich
# Processing Record 25 of Set 14 | hirara
# Processing Record 26 of Set 14 | gazli
# Processing Record 27 of Set 14 | sokolo
# Processing Record 28 of Set 14 | sakakah
# Processing Record 29 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 14 | champerico
# Processing Record 31 of Set 14 | deniliquin
# Processing Record 32 of Set 14 | guanica
# Processing Record 33 of Set 14 | tuy hoa
# Processing Record 34 of Set 14 | ancud
# Processing Record 35 of Set 14 | turukhansk
# Processing Record 36 of Set 14 | hobyo
# Processing Record 37 of Set 14 | nchelenge
# Processing Record 38 of Set 14 | severo-yeniseyskiy
# Processing Record 39 of Set 14 | mandan
# Processing Record 40 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 14 | oranjemund
# Processing Record 42 of Set 14 | safaqis
# City not found. Skipping...
# Processing Record 43 of Set 14 | touros
# Processing Record 44 of Set 14 | pasighat
# Processing Record 45 of Set 14 | loreto
# Processing Record 46 of Set 14 | ulladulla
# Processing Record 47 of Set 14 | pirganj
# Processing Record 48 of Set 14 | yefimovskiy
# City not found. Skipping...
# Processing Record 49 of Set 14 | bilibino
# Processing Record 50 of Set 14 | lhokseumawe
# Processing Record 1 of Set 15 | eydhafushi
# Processing Record 2 of Set 15 | ixtapa
# Processing Record 3 of Set 15 | ust-shonosha
# Processing Record 4 of Set 15 | natal
# Processing Record 5 of Set 15 | shillong
# Processing Record 6 of Set 15 | hun
# Processing Record 7 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 15 | kihei
# Processing Record 9 of Set 15 | berezovka
# Processing Record 10 of Set 15 | auki
# Processing Record 11 of Set 15 | garachine
# Processing Record 12 of Set 15 | karratha
# Processing Record 13 of Set 15 | bolshaya rechka
# Processing Record 14 of Set 15 | rudnya
# Processing Record 15 of Set 15 | floro
# Processing Record 16 of Set 15 | singkang
# Processing Record 17 of Set 15 | qasigiannguit
# Processing Record 18 of Set 15 | la paz
# Processing Record 19 of Set 15 | gornopravdinsk
# Processing Record 20 of Set 15 | askiz
# Processing Record 21 of Set 15 | boda
# Processing Record 22 of Set 15 | muli
# Processing Record 23 of Set 15 | springbok
# Processing Record 24 of Set 15 | sobolevo
# Processing Record 25 of Set 15 | panama city
# Processing Record 26 of Set 15 | luau
# Processing Record 27 of Set 15 | ursulo galvan
# Processing Record 28 of Set 15 | sechura
# Processing Record 29 of Set 15 | reinosa
# Processing Record 30 of Set 15 | sharlyk
# Processing Record 31 of Set 15 | brownsville
# Processing Record 32 of Set 15 | batticaloa
# Processing Record 33 of Set 15 | camana
# Processing Record 34 of Set 15 | kerman
# Processing Record 35 of Set 15 | hokitika
# Processing Record 36 of Set 15 | teluk nibung
# Processing Record 37 of Set 15 | matara
# Processing Record 38 of Set 15 | grand-lahou
# Processing Record 39 of Set 15 | visnes
# Processing Record 40 of Set 15 | trelew
# Processing Record 41 of Set 15 | vagay
# Processing Record 42 of Set 15 | mokhsogollokh
# Processing Record 43 of Set 15 | nyurba
# Processing Record 44 of Set 15 | te anau
# Processing Record 45 of Set 15 | caravelas
# Processing Record 46 of Set 15 | richards bay
# Processing Record 47 of Set 15 | sungurlu
# Processing Record 48 of Set 15 | zhangye
# Processing Record 49 of Set 15 | outjo
# Processing Record 50 of Set 15 | hohhot
# Processing Record 1 of Set 16 | mujiayingzi
# Processing Record 2 of Set 16 | srandakan
# Processing Record 3 of Set 16 | piacabucu
# Processing Record 4 of Set 16 | manhattan
# Processing Record 5 of Set 16 | puerto madero
# Processing Record 6 of Set 16 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 16 | itanhem
# Processing Record 8 of Set 16 | nago
# Processing Record 9 of Set 16 | veraval
# Processing Record 10 of Set 16 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 16 | eastbourne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=eastbourne&appid=b274e26d5f31fc8e75534bcafd251b30&units=imperial

# %%
# Before exporting your new DataFrame as a CSV file, take a moment to confirm that it looks similar to the image below:
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bambous Virieux -20.3428   57.7575     66.45        94          75
# 1          Ushuaia -54.8000  -68.3000     37.06        93          90
# 2            Nioro  13.3500  -15.7500     87.51        58          66
# 3             Aksu  41.1231   80.2644     88.93        28          61
# 4   Cabo San Lucas  22.8909 -109.9124     97.52        66           7
# 5            Ambon  -3.6954  128.1814     77.14       100          40
# 6            Pevek  69.7008  170.3133     33.96        93         100
# 7           Bethel  41.3712  -73.4140     91.35        52           1
# 8          Emerald -23.5333  148.1667     52.99        71           4
# 9        Busselton -33.6500  115.3333     46.09        66          93
#
#    Wind Speed Country                 Date Current Description
# 0       14.97      MU  2021-07-27 17:49:41                Rain
# 1        4.61      AR  2021-07-27 17:44:00              Clouds
# 2        9.95      GM  2021-07-27 17:49:42              Clouds
# 3       11.83      CN  2021-07-27 17:49:42              Clouds
# 4        5.01      MX  2021-07-27 17:49:42               Clear
# 5        3.44      ID  2021-07-27 17:49:42              Clouds
# 6       14.63      RU  2021-07-27 17:49:43              Clouds
# 7        1.01      US  2021-07-27 17:49:43               Clear
# 8        4.61      AU  2021-07-27 17:46:32               Clear
# 9       12.39      AU  2021-07-27 17:49:43              Clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).
output_data_file = "../Weather_Database/weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
